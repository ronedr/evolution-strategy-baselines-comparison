# %%
import sys
sys.path.append('/home/ronedr/evolution-strategy-baselines-comparison')

# %%
from tqdm import tqdm
import optax
from evosax.problems import BBOBProblem as Problem, bbob_fns
from utils.problem_utils import get_problem_settings
from experiment.run_experiments import run_experiment_permutations
from evosax.core.fitness_shaping import standardize_fitness_shaping_fn

# %%
num_generations = 1024
population_size = 256
num_dims = 10
seeds = list(range(0, 5))
result_dir = "../../results"
problems_bbob_fns = list(bbob_fns.keys())

# %%
es_dict = {
    "PGPE": {
        "optimizer": optax.adam(learning_rate=0.02),
    },
    "ASEBO": {
        "optimizer": optax.adam(learning_rate=0.01),
        "fitness_shaping_fn": standardize_fitness_shaping_fn
    },
    "LES": {
        "optimizer": optax.adam(learning_rate=0.01)
    },
    "Open_ES": {    
        "optimizer": optax.adam(learning_rate=0.05)
    },
    "SNES": {},
    "Sep_CMA_ES": {},
    "CMA_ES": {},
    "LES": {},
    "DES": {},
    # "EvoTF_ES": {},
}

# take only the es_algorithms we insert as arg.
running_es = es_dict

# %%
for bbob_fn in tqdm(problems_bbob_fns, desc="Loading Problems .."):
    try:
        problem = Problem(fn_name=bbob_fn, num_dims=num_dims)
        print("Successfully loaded:", bbob_fn)
        run_experiment_permutations(problems=[problem],
                                    es_dict=running_es,
                                    num_generations=num_generations,
                                    population_size=population_size,
                                    result_dir=result_dir, 
                                    run_again_if_exist=True,
                                    seeds=list(range(0, 5)))
    except Exception as e:
        print("Failed to load:", bbob_fn, e)
        continue
# Out:
# Loading Problems ..:   0%|          | 0/24 [00:00<?, ?it/s]2025-10-13 13:00:41.435345: W external/xla/xla/service/platform_util.cc:211] unable to create StreamExecutor for CUDA:0: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# Loading Problems ..:   4%|▍         | 1/24 [00:00<00:10,  2.14it/s]
# Failed to load: sphere Unable to initialize backend 'cuda': INTERNAL: no supported devices found for platform CUDA (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)
# Successfully loaded: ellipsoidal
# Running ES algorithms:   0%|          | 0/8 [00:00<?, ?it/s]
# running the experiment ... [../../results/BBOBProblem/ellipsoidal/PGPE/0]
# Generation 016 | Mean fitness (Test): 3066634.50
# Generation 032 | Mean fitness (Test): 2422755.00
# Generation 048 | Mean fitness (Test): 1890228.38
# Generation 064 | Mean fitness (Test): 926206.81
# Generation 080 | Mean fitness (Test): 713004.31
# Generation 096 | Mean fitness (Test): 400655.78
# Generation 112 | Mean fitness (Test): 272611.34
# Generation 128 | Mean fitness (Test): 184509.62
# Running ES algorithms:   0%|          | 0/8 [00:09<?, ?it/s]
# Loading Problems ..:   4%|▍         | 1/24 [00:11<04:16, 11.17s/it]
# Exception ignored in: <function _xla_gc_callback at 0x7f3a97276660>
# Traceback (most recent call last):
#   File "/home/ronedr/.local/lib/python3.11/site-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
# KeyboardInterrupt:
# Exception ignored in: <function _xla_gc_callback at 0x7f3a97276660>
# Traceback (most recent call last):
#   File "/home/ronedr/.local/lib/python3.11/site-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
#
# KeyboardInterrupt
