# %% [markdown]
# # 02 - Reinforcement Learning - Evolving MLP [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RobertTLange/evosax/blob/main/examples/02_rl.ipynb)

# %% [markdown]
# ## Installation

# %% [markdown]
# You will need Python 3.10 or later, and a working JAX installation. For example, you can install JAX on NVIDIA GPU with:

# %%
# %pip install -U "jax[cuda]"

# %% [markdown]
# Then, install `evosax` from PyPi:

# %%
# %pip install -U "evosax[examples]"

# %% [markdown]
# ## Import

# %%
import jax
import matplotlib.pyplot as plt
import optax

# %%
seed = 0
key = jax.random.key(seed)

# %% [markdown]
# ## Gymnax

# %% [markdown]
# ### CartPole environment

# %%
from evosax.problems import GymnaxProblem as Problem
from evosax.problems.networks import MLP, categorical_output_fn

policy = MLP(
    layer_sizes=(64, 64, 2),
    output_fn=categorical_output_fn,
)

problem = Problem(
    env_name="CartPole-v1",
    policy=policy,
    episode_length=200,
    num_rollouts=16,
    use_normalize_obs=True,
)

key, subkey = jax.random.split(key)
problem_state = problem.init(key)

key, subkey = jax.random.split(key)
solution = problem.sample(subkey)

# %%
print(f"Number of pararmeters: {sum(leaf.size for leaf in jax.tree.leaves(solution))}")
# Out:
# Number of pararmeters: 4610

# %% [markdown]
# ### SNES

# %%
from evosax.algorithms import LearnedES as ES

num_generations = 1000
population_size = 128

es = ES(
    population_size=population_size,
    solution=solution,
)

params = es.default_params

# %% [markdown]
# ### Run

# %%
def step(carry, key):
    state, params, problem_state = carry
    key_ask, key_eval, key_tell = jax.random.split(key, 3)

    population, state = es.ask(key_ask, state, params)

    fitness, problem_state, _ = problem.eval(key_eval, population, problem_state)

    state, metrics = es.tell(
        key_tell, population, -fitness, state, params
    )  # Minimize fitness

    return (state, params, problem_state), metrics

# %%
key, subkey = jax.random.split(key)
state = es.init(subkey, solution, params)

key, subkey = jax.random.split(key)
keys = jax.random.split(subkey, num_generations)
(state, params, problem_state), metrics = jax.lax.scan(
    step,
    (state, params, problem_state),
    keys,
)

# %%
plt.figure(figsize=(6, 3))
plt.plot(-metrics["best_fitness_in_generation"])

plt.title("SNES on CartPole task")
plt.xlabel("Generations")
plt.ylabel("Fitness")

plt.grid(True)
plt.tight_layout()

plt.show()

# %%
mean_solution = es.get_mean(state)
fitness, _, info = problem.eval(key,
                                jax.tree.map(lambda x: x[None], mean_solution),
                                problem_state)

# %%
rollout = [
    jax.tree_util.tree_map(lambda x: x[0, 0, t], info["env_states"][1])
    for t in range(problem.episode_length)
]

# %%
fitness
# Out:
# Array([200.], dtype=float32)

# %% [markdown]
# ## Brax

# %% [markdown]
# ### Ant environment

# %%
from evosax.problems import BraxProblem as Problem
from evosax.problems.networks import MLP, tanh_output_fn

problem = Problem(
            num_rollouts=1,
            env_name='ant',
            policy=MLP(
                layer_sizes=(32, 32, 32, 32, 8),
                output_fn=tanh_output_fn,
            ),
            episode_length=1000
        )

key, subkey = jax.random.split(key)
problem_state = problem.init(key)

key, subkey = jax.random.split(key)
solution = problem.sample(subkey)

# %%
print(f"Number of pararmeters: {sum(leaf.size for leaf in jax.tree.leaves(solution))}")
# Out:
# Number of pararmeters: 4328

# %% [markdown]
# ### Open_ES

# %%
from evosax.algorithms import EvoTF_ES as ES

num_generations = 1000
population_size = 256

# lr_schedule = optax.exponential_decay(
#     init_value=0.01,
#     transition_steps=num_generations,
#     decay_rate=0.1,
# )
# std_schedule = optax.exponential_decay(
#     init_value=0.05,
#     transition_steps=num_generations,
#     decay_rate=0.2,
# )
es = ES(
    population_size=population_size,
    solution=solution,
    # optimizer=optax.adam(learning_rate=lr_schedule),
    # std_schedule=std_schedule,
)

params = es.default_params

# %% [markdown]
# ### Run

# %%
def step(carry, key):
    state, params, problem_state = carry
    key_ask, key_eval, key_tell = jax.random.split(key, 3)

    population, state = es.ask(key_ask, state, params)

    fitness, problem_state, _ = problem.eval(key_eval, population, problem_state)

    state, metrics = es.tell(
        key_tell, population, -fitness, state, params
    )  # Minimize fitness

    return (state, params, problem_state), metrics

# %%
key, subkey = jax.random.split(key)
state = es.init(subkey, solution, params)

fitness_log = []
log_period = 1
for i in range(num_generations // log_period):
    # Train
    key, subkey = jax.random.split(key)
    keys = jax.random.split(subkey, log_period)
    (state, params, problem_state), metrics = jax.lax.scan(
        step,
        (state, params, problem_state),
        keys,
    )
    # Eval
    mean = es.get_mean(state)
    key, subkey = jax.random.split(key)
    fitness, problem_state, info = problem.eval(
        key, jax.tree.map(lambda x: x[None], mean), problem_state
    )
    print(f"Generation {(i + 1) * log_period:3d} | Mean fitness: {fitness.mean():.2f}")
# Out:
# 2025-11-08 22:54:51.947727: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:51.947794: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:51.947818: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:51.947911: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:51.947932: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 19.82GiB (21277179920 bytes), down from 19.82GiB (21277179920 bytes) originally
# 2025-11-08 22:54:51.947947: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:51.948095: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:51.980033: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.025733: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.039157: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.058360: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.059489: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.124304: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.134660: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.204565: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.231943: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:52.363854: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below -910.48MiB (-954709483 bytes) by rematerialization; only reduced to 13.21GiB (14181990400 bytes), down from 13.21GiB (14181990400 bytes) originally
# 2025-11-08 22:54:53.028426: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.046932: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.183321: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.245219: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.281859: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.353319: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.370231: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.462969: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.478255: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.547189: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.634109: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.661452: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.776113: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.839222: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.924978: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.925067: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.938758: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:53.971386: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 27.94GiB (30002427920 bytes), down from 27.94GiB (30002427920 bytes) originally
# 2025-11-08 22:54:54.014228: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:54.043088: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:54.157740: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:54.191170: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:54.418439: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:54.559618: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 4.62GiB (4965996522 bytes) by rematerialization; only reduced to 13.96GiB (14985267200 bytes), down from 13.96GiB (14985267200 bytes) originally
# 2025-11-08 22:54:56.868397: W external/xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[53], line 10
#       8 key, subkey = jax.random.split(key)
#       9 keys = jax.random.split(subkey, log_period)
# ---> 10 (state, params, problem_state), metrics = jax.lax.scan(
#      11     step,
#      12     (state, params, problem_state),
#      13     keys,
#      14 )
#      15 # Eval
#      16 mean = es.get_mean(state)
#
#     [... skipping hidden 18 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/compiler.py:324, in backend_compile(backend, module, options, host_callbacks)
#     318     return backend.compile(
#     319         built_c, compile_options=options, host_callbacks=host_callbacks
#     320     )
#     321   # Some backends don't have `host_callbacks` option yet
#     322   # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     323   # to take in `host_callbacks`
# --> 324   return backend.compile(built_c, compile_options=options)
#     325 except xc.XlaRuntimeError as e:
#     326   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 7107772416 bytes.

# %%
metrics
# Out:
# {'best_fitness': Array([-2651.6587, -2706.6482, -2706.6482, -2706.6482, -2726.829 ],      dtype=float32),
#  'best_fitness_in_generation': Array([-2651.6587, -2706.6482, -2691.2583, -2693.6926, -2726.829 ],      dtype=float32),
#  'best_solution': Array([[-0.07395826,  0.05794974,  0.02122748, ...,  0.01772279,
#          -0.03414154,  0.29587388],
#         [-0.0676754 ,  0.0684135 ,  0.00832836, ...,  0.01018975,
#          -0.02111087,  0.27350175],
#         [-0.0676754 ,  0.0684135 ,  0.00832836, ...,  0.01018975,
#          -0.02111087,  0.27350175],
#         [-0.0676754 ,  0.0684135 ,  0.00832836, ...,  0.01018975,
#          -0.02111087,  0.27350175],
#         [-0.07745133,  0.07000981,  0.01661149, ...,  0.03493666,
#          -0.03384582,  0.28435102]], dtype=float32),
#  'best_solution_in_generation': Array([[-0.07395826,  0.05794974,  0.02122748, ...,  0.01772279,
#          -0.03414154,  0.29587388],
#         [-0.0676754 ,  0.0684135 ,  0.00832836, ...,  0.01018975,
#          -0.02111087,  0.27350175],
#         [-0.04298713,  0.07716472,  0.01884395, ...,  0.03313677,
#          -0.02377005,  0.27534175],
#         [-0.06227349,  0.06826639,  0.01571497, ...,  0.03051531,
#          -0.03473581,  0.27323174],
#         [-0.07745133,  0.07000981,  0.01661149, ...,  0.03493666,
#          -0.03384582,  0.28435102]], dtype=float32),
#  'best_solution_norm': Array([12.132691, 12.132105, 12.132105, 12.132105, 12.121663], dtype=float32),
#  'generation_counter': Array([95, 96, 97, 98, 99], dtype=int32, weak_type=True),
#  'mean': Array([[-0.07492216,  0.06583948,  0.01106554, ...,  0.01650903,
#          -0.0363758 ,  0.28338078],
#         [-0.07448612,  0.066241  ,  0.01140252, ...,  0.0167545 ,
#          -0.03645747,  0.28306764],
#         [-0.07418471,  0.06673495,  0.01150542, ...,  0.01691636,
#          -0.03666048,  0.28264162],
#         [-0.07368342,  0.06706664,  0.01158838, ...,  0.01707367,
#          -0.03699388,  0.28216603],
#         [-0.07335368,  0.06747136,  0.01169666, ...,  0.01721171,
#          -0.03725998,  0.28179023]], dtype=float32),
#  'mean_norm': Array([12.107351, 12.107673, 12.107822, 12.107798, 12.107902], dtype=float32)}

# %%
mean = es._unravel_solution(state.best_solution)
key, subkey = jax.random.split(key)
fitness, problem_state, info = problem.eval(
    key, jax.tree.map(lambda x: x[None], mean), problem_state
)
print(f"Generation {(i + 1) * log_period:3d} | Mean fitness: {fitness.mean():.2f}")
# Out:
# Generation 100 | Mean fitness: 2680.10

# %%
mean = es._unravel_solution(state.mean)
key, subkey = jax.random.split(key)
fitness, problem_state, info = problem.eval(
    key, jax.tree.map(lambda x: x[None], mean), problem_state
)
print(f"Generation {(i + 1) * log_period:3d} | Mean fitness: {fitness.mean():.2f}")
# Out:
# Generation 100 | Mean fitness: 2660.46

# %%
key, subkey = jax.random.split(key)
state = es.init(subkey, solution, params)

fitness_log = []
log_period = 5
for i in range(num_generations // log_period):
    # Train
    key, subkey = jax.random.split(key)
    keys = jax.random.split(subkey, log_period)
    (state, params, problem_state), metrics = jax.lax.scan(
        step,
        (state, params, problem_state),
        keys,
    )
    # Eval
    mean = es.get_mean(state)
    key, subkey = jax.random.split(key)
    fitness, problem_state, info = problem.eval(
        key, jax.tree.map(lambda x: x[None], mean), problem_state
    )
    print(f"Generation {(i + 1) * log_period:3d} | Mean fitness: {fitness.mean():.2f}")
# Out:
# Generation   5 | Mean fitness: 773.96
# Generation  10 | Mean fitness: 776.44
# Generation  15 | Mean fitness: 785.46
# Generation  20 | Mean fitness: 775.63
# Generation  25 | Mean fitness: 768.76
# Generation  30 | Mean fitness: 75.38
# Generation  35 | Mean fitness: 718.73
# Generation  40 | Mean fitness: 729.40
# Generation  45 | Mean fitness: 727.76
# Generation  50 | Mean fitness: 688.18
# Generation  55 | Mean fitness: 716.37
# Generation  60 | Mean fitness: 710.29
# Generation  65 | Mean fitness: 749.82
# Generation  70 | Mean fitness: 715.34
# Generation  75 | Mean fitness: 725.74
# Generation  80 | Mean fitness: 717.93
# Generation  85 | Mean fitness: 720.38
# Generation  90 | Mean fitness: 745.57
# Generation  95 | Mean fitness: 709.01
# Generation 100 | Mean fitness: 704.99

# %%
mean = es._unravel_solution(state.best_solution)
key, subkey = jax.random.split(key)
fitness, problem_state, info = problem.eval(
    key, jax.tree.map(lambda x: x[None], mean), problem_state
)
print(f"Generation {(i + 1) * log_period:3d} | Mean fitness: {fitness.mean():.2f}")
# Out:
# Generation 100 | Mean fitness: -850.16

# %%
mean = es._unravel_solution(state.mean)
key, subkey = jax.random.split(key)
fitness, problem_state, info = problem.eval(
    key, jax.tree.map(lambda x: x[None], mean), problem_state
)
print(f"Generation {(i + 1) * log_period:3d} | Mean fitness: {fitness.mean():.2f}")
# Out:
# Generation 100 | Mean fitness: 766.92

# %%
metrics
# Out:
# {'best_fitness': Array([6.7557936, 6.7557936, 6.7557936, 6.7557936, 6.7557936], dtype=float32),
#  'best_fitness_in_generation': Array([26.322433, 14.506347, 21.014194, 27.467209, 12.992955], dtype=float32),
#  'best_solution': Array([[1.7560409, 2.6212163, 1.1966957, ..., 1.8031565, 0.3642707,
#          1.0150014],
#         [1.7560409, 2.6212163, 1.1966957, ..., 1.8031565, 0.3642707,
#          1.0150014],
#         [1.7560409, 2.6212163, 1.1966957, ..., 1.8031565, 0.3642707,
#          1.0150014],
#         [1.7560409, 2.6212163, 1.1966957, ..., 1.8031565, 0.3642707,
#          1.0150014],
#         [1.7560409, 2.6212163, 1.1966957, ..., 1.8031565, 0.3642707,
#          1.0150014]], dtype=float32),
#  'best_solution_in_generation': Array([[ 0.18801151, -0.43639562,  1.0129931 , ...,  1.0345311 ,
#          -0.7331841 ,  1.9324782 ],
#         [-1.0630109 , -1.1922959 ,  0.56556016, ..., -1.1041806 ,
#          -0.4068186 , -1.625924  ],
#         [-2.3555593 , -0.6813465 , -0.09897268, ..., -0.804518  ,
#          -1.3715498 , -0.54216677],
#         [ 0.6376676 ,  1.8273231 ,  0.14930193, ...,  0.72951615,
#          -0.04270397,  1.270236  ],
#         [-1.8013936 ,  0.15263431, -0.7223487 , ..., -0.06200962,
#          -1.083094  ,  1.7907515 ]], dtype=float32),
#  'best_solution_norm': Array([66.05389, 66.05389, 66.05389, 66.05389, 66.05389], dtype=float32),
#  'generation_counter': Array([95, 96, 97, 98, 99], dtype=int32, weak_type=True),
#  'mean': Array([[-0.08114074,  0.00177064, -0.04851216, ...,  0.02934013,
#          -0.19647174,  0.28415513],
#         [-0.08100682,  0.00208881, -0.04842483, ...,  0.02907532,
#          -0.19678213,  0.28367695],
#         [-0.08103923,  0.00250315, -0.04825823, ...,  0.02879975,
#          -0.19722632,  0.28320557],
#         [-0.08092725,  0.00286139, -0.04815463, ...,  0.0286319 ,
#          -0.19764964,  0.2827847 ],
#         [-0.0807818 ,  0.00312029, -0.04835258, ...,  0.02831218,
#          -0.1981931 ,  0.2824077 ]], dtype=float32),
#  'mean_norm': Array([12.201975 , 12.202501 , 12.202999 , 12.2033825, 12.203556 ],      dtype=float32)}

# %%
fitness, problem_state, info= problem.eval(
        key, jax.tree.map(lambda x: x[None], mean), problem_state
    )

# %%
problem_state
# Out:
# State(counter=Array(51, dtype=int32, weak_type=True), obs_mean=Array([ 6.6776901e-01,  7.0064437e-01,  8.5503451e-04,  2.3383384e-04,
#        -6.0958148e-04,  2.5634472e-03,  8.6579204e-01, -9.7037683e-04,
#        -8.6184609e-01, -1.3890807e-03, -8.6179113e-01,  1.7096665e-04,
#         8.5905850e-01,  4.2262082e-03,  4.2606336e-03,  8.4686168e-02,
#         6.4107594e-03,  2.4981920e-03,  1.1049273e-03,  3.0101952e-03,
#        -3.2504156e-02,  7.9411583e-04,  2.9354932e-02, -1.6561612e-03,
#         3.2883044e-02, -2.6031581e-03, -3.4305204e-02], dtype=float32), obs_std=Array([0.12801035, 0.46051726, 0.16092971, 0.16142605, 0.4951359 ,
#        0.51651037, 0.39701605, 0.51622516, 0.39682817, 0.51626426,
#        0.39682811, 0.516803  , 0.3972082 , 1.0152478 , 1.0160161 ,
#        0.9787275 , 1.3322144 , 1.3280946 , 2.7877662 , 4.664691  ,
#        5.168439  , 4.6644187 , 5.1770153 , 4.6638465 , 5.185604  ,
#        4.658945  , 5.17264   ], dtype=float32), obs_var_sum=Array([1.5962236e+05, 2.0658338e+06, 2.5227606e+05, 2.5383459e+05,
#        2.3880992e+06, 2.5987332e+06, 1.5353934e+06, 2.5958638e+06,
#        1.5339406e+06, 2.5962570e+06, 1.5339401e+06, 2.6016785e+06,
#        1.5368801e+06, 1.0040323e+07, 1.0055525e+07, 9.3309780e+06,
#        1.7288280e+07, 1.7181518e+07, 7.5703552e+07, 2.1195774e+08,
#        2.6020902e+08, 2.1193304e+08, 2.6107328e+08, 2.1188104e+08,
#        2.6194026e+08, 2.1143590e+08, 2.6063221e+08], dtype=float32), obs_counter=Array(9741000, dtype=int32, weak_type=True), std_min=Array(1.e-06, dtype=float32, weak_type=True), std_max=Array(1000000., dtype=float32, weak_type=True))

# %% [markdown]
# ## Visualize policy

# %%
mean = es.get_mean(state)
mean = es._unravel_solution(state.best_solution)

key, subkey = jax.random.split(key)
fitness, problem_state, info = problem.eval(
    key, jax.tree.map(lambda x: x[None], mean), problem_state
)
fitness[0]
# Out:
# Array(898.937, dtype=float32)

# %%
from brax.io import html
from IPython.display import HTML

rollout = [
    jax.tree_util.tree_map(lambda x: x[0, 0, t], info["env_states"].pipeline_state)
    for t in range(problem.episode_length)
]

html_content = html.render(
    problem.env.sys.tree_replace({"opt.timestep": problem.env.dt}), rollout
)
HTML(html_content)

# Write to file
with open("ant_visualization.html", "w") as f:
    f.write(html_content)

print("Visualization saved to 'ant_visualization.html'")
# Out:
# Visualization saved to 'ant_visualization.html'

# %%
# Out:
# Visualization saved to 'ant_visualization.html'

# %%
import jax
import gymnax

key = jax.random.key(0)
key, key_reset, key_act, key_step = jax.random.split(key, 4)

# Instantiate the environment & its settings.
env, env_params = gymnax.make("CartPole-v1")

# Reset the environment.
obs, state = env.reset(key_reset, env_params)

# Sample a random action.
action = env.action_space(env_params).sample(key_act)

# Perform the step transition.
n_obs, n_state, reward, done, _ = env.step(key_step, state, action, env_params)
# Out:
# /home/ronedr/.local/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:122: UserWarning: Explicitly requested dtype <class 'jax.numpy.int64'> requested in astype is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return lax_numpy.astype(self, dtype, copy=copy, device=device)

# %%
from gymnax.visualize import Visualizer
import jax.numpy as jnp

state_seq, reward_seq = [], []
key, key_reset = jax.random.split(key)
obs, env_state = env.reset(key_reset, env_params)
while True:
    state_seq.append(env_state)
    key, key_act, key_step = jax.random.split(key, 3)
    action = env.action_space(env_params).sample(key_act)
    next_obs, next_env_state, reward, done, info = env.step(
        key_step, env_state, action, env_params
    )
    reward_seq.append(reward)
    if done:
        break
    else:
      obs = next_obs
      env_state = next_env_state

cum_rewards = jnp.cumsum(jnp.array(reward_seq))
vis = Visualizer(env, env_params, state_seq, cum_rewards)
vis.animate(f"anim.gif")
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/animation.py:243, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     242 try:
# --> 243     yield self
#     244 finally:
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/animation.py:1092, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1091 for anim in all_anim:
# -> 1092     anim._init_draw()  # Clear the initial frame
#    1093 frame_number = 0
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/animation.py:1751, in FuncAnimation._init_draw(self)
#    1750 else:
# -> 1751     self._drawn_artists = self._init_func()
#    1752     if self._blit:
#
# File ~/.local/lib/python3.11/site-packages/gymnax/visualize/visualizer.py:64, in Visualizer.init(self)
#      57 if self.env.name in [
#      58     "Acrobot-v1",
#      59     "CartPole-v1",
#    (...)
#      62     "MountainCarContinuous-v0",
#      63 ]:
# ---> 64     self.im = vis_gym.init_gym(
#      65         self.ax, self.env, self.state_seq[0], self.env_params
#      66     )
#      67 elif self.env.name == "Catch-bsuite":
#
# File ~/.local/lib/python3.11/site-packages/gymnax/visualize/vis_gym.py:55, in init_gym(ax, env, state, params)
#      54 gym_env.env.state = gym_state
# ---> 55 rgb_array = gym_env.render(mode="rgb_array")
#      56 ax.set_xticks([])
#
# TypeError: Wrapper.render() got an unexpected keyword argument 'mode'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 23
#      21 cum_rewards = jnp.cumsum(jnp.array(reward_seq))
#      22 vis = Visualizer(env, env_params, state_seq, cum_rewards)
# ---> 23 vis.animate(f"anim.gif")
#
# File ~/.local/lib/python3.11/site-packages/gymnax/visualize/visualizer.py:48, in Visualizer.animate(self, save_fname, view)
#      46 # Save the animation to a gif
#      47 if save_fname is not None:
# ---> 48     ani.save(save_fname)
#      49 # Simply view it 3 times
#      50 if view:
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1085 savefig_kwargs['transparent'] = False   # just to be safe!
#    1086 # canvas._is_saving = True makes the draw_event animation-starting
#    1087 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1088 # widget (both are likewise done in savefig()).
# -> 1089 with writer.saving(self._fig, filename, dpi), \
#    1090      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1091     for anim in all_anim:
#    1092         anim._init_draw()  # Clear the initial frame
#
# File /storage/modules/packages/anaconda/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/animation.py:245, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     243     yield self
#     244 finally:
# --> 245     self.finish()
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/animation.py:515, in PillowWriter.finish(self)
#     514 def finish(self):
# --> 515     self._frames[0].save(
#     516         self.outfile, save_all=True, append_images=self._frames[1:],
#     517         duration=int(1000 / self.fps), loop=0)
#
# IndexError: list index out of range
# Error in callback <function _draw_all_if_interactive at 0x7fb2cf7bc540> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/figure.py:3164, in Figure.draw(self, renderer)
#    3161 finally:
#    3162     self.stale = False
# -> 3164 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/backend_bases.py:1271, in Event._process(self)
#    1269 def _process(self):
#    1270     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1271     self.canvas.callbacks.process(self.name, self)
#    1272     self._guiEvent_deleted = True
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/animation.py:912, in Animation._start(self, *args)
#     909 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     911 # Now do any initial draw
# --> 912 self._init_draw()
#     914 # Add our callback for stepping the animation and
#     915 # actually start the event_source.
#     916 self.event_source.add_callback(self._step)
#
# File /storage/modules/packages/anaconda/lib/python3.11/site-packages/matplotlib/animation.py:1751, in FuncAnimation._init_draw(self)
#    1749     self._draw_frame(frame_data)
#    1750 else:
# -> 1751     self._drawn_artists = self._init_func()
#    1752     if self._blit:
#    1753         if self._drawn_artists is None:
#
# File ~/.local/lib/python3.11/site-packages/gymnax/visualize/visualizer.py:64, in Visualizer.init(self)
#      56 """Plot placeholder points."""
#      57 if self.env.name in [
#      58     "Acrobot-v1",
#      59     "CartPole-v1",
#    (...)
#      62     "MountainCarContinuous-v0",
#      63 ]:
# ---> 64     self.im = vis_gym.init_gym(
#      65         self.ax, self.env, self.state_seq[0], self.env_params
#      66     )
#      67 elif self.env.name == "Catch-bsuite":
#      68     self.im = vis_catch.init_catch(
#      69         self.ax, self.env, self.state_seq[0], self.env_params
#      70     )
#
# File ~/.local/lib/python3.11/site-packages/gymnax/visualize/vis_gym.py:55, in init_gym(ax, env, state, params)
#      53     gym_env.env.last_u = gym_state[-1]
#      54 gym_env.env.state = gym_state
# ---> 55 rgb_array = gym_env.render(mode="rgb_array")
#      56 ax.set_xticks([])
#      57 ax.set_yticks([])
#
# TypeError: Wrapper.render() got an unexpected keyword argument 'mode'
