# %%
import sys
sys.path.append('/home/ronedr/evolution-strategy-baselines-comparison')

# %%
import jax
import optax
from tqdm import tqdm
import gymnax
from evosax.problems import GymnaxProblem as Problem
from utils.nn_model import CNN
from utils.problem_utils import get_problem_settings
from experiment.run_experiments import run_experiment_permutations
from evosax.core.fitness_shaping import standardize_fitness_shaping_fn

# %%
num_generations = 5000
population_size = 256
eval_batch_size = 128
log_period = 1
seeds = list(range(0, 5))
result_dir = "../../results"
problems_gymnax = ['Asterix-MinAtar',
                   'Breakout-MinAtar',
                   'Freeway-MinAtar',
                   'SpaceInvaders-MinAtar']

# %%
es_dict = {
    "PGPE": {
        "optimizer": optax.adam(learning_rate=0.02),
    },
    "ASEBO": {
        "optimizer": optax.adam(learning_rate=0.01),
        "fitness_shaping_fn": standardize_fitness_shaping_fn
    },
    "Open_ES": {    
        "optimizer": optax.adam(learning_rate=0.05)
    },
    "SNES": {},
    "Sep_CMA_ES": {},
    "CMA_ES": {},
    "LES": {},
    "DES": {},
    # "EvoTF_ES": {},
}

# take only the es_algorithms we insert as arg.
running_es = es_dict

# %%
for env_name in tqdm(problems_gymnax, desc="Loading Problems .."):
    try:
        action_num, out_fn = get_problem_settings(env_name)
        problem = Problem(
            env_name=env_name,
            policy=CNN(
                num_filters=[16],
                kernel_sizes=[(5, 5)],
                strides=(1, 1),
                mlp_layer_sizes=[32, action_num]
            ),
            num_rollouts=1,
            episode_length=500
        )
        print("Successfully loaded:", env_name)
        
        run_experiment_permutations(problems=[problem],
                                    es_dict=running_es,
                                    num_generations=num_generations,
                                    population_size=population_size,
                                    result_dir=result_dir, 
                                    run_again_if_exist=False,
                                    log_period=log_period,
                                    eval_batch_size=eval_batch_size,
                                    seeds=list(range(0, 5)))
    except Exception as e:
        print("Failed to load:", env_name, e)
        continue
# Out:
# Loading Problems ..:   0%|          | 0/4 [00:00<?, ?it/s]/home/ronedr/.local/lib/python3.11/site-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int32 to dtype=bool with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# 2025-10-13 13:00:07.224317: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:864] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.
# 2025-10-13 13:00:07.224336: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:867] Conv: %cudnn-conv.1 = (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,4,10,10]{3,2,1,0} %bitcast.39, f32[16,4,5,5]{3,2,1,0} %bitcast.46), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(conv_general_dilated)/jit(main)/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# Loading Problems ..:  25%|██▌       | 1/4 [00:01<00:03,  1.28s/it]/home/ronedr/.local/lib/python3.11/site-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=float32 to dtype=bool with jax_numpy_dtype_promotion='standard'. In future JAX releases this will result in an error.
#   warnings.warn(
# Failed to load: Asterix-MinAtar UNKNOWN: Failed to determine best cudnn convolution algorithm for:
# %cudnn-conv.1 = (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,4,10,10]{3,2,1,0} %bitcast.39, f32[16,4,5,5]{3,2,1,0} %bitcast.46), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(conv_general_dilated)/jit(main)/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
#
# Original error: INTERNAL: All algorithms tried for (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,4,10,10]{3,2,1,0}, f32[16,4,5,5]{3,2,1,0}), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} failed. Falling back to default algorithm.  Per-algorithm errors:
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=3,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng3{k11=2}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng4{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#
# To ignore this failure and try to use a fallback algorithm (which may have suboptimal performance), use XLA_FLAGS=--xla_gpu_strict_conv_algorithm_picker=false.  Please also file a bug for the root cause of failing autotuning.
# 2025-10-13 13:00:07.699908: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:864] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.
# 2025-10-13 13:00:07.699924: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:867] Conv: %cudnn-conv.1 = (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,4,10,10]{3,2,1,0} %bitcast.39, f32[16,4,5,5]{3,2,1,0} %bitcast.46), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(conv_general_dilated)/jit(main)/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# Loading Problems ..:  50%|█████     | 2/4 [00:01<00:01,  1.25it/s]/home/ronedr/.local/lib/python3.11/site-packages/gymnax/environments/minatar/freeway.py:278: UserWarning: Explicitly requested dtype <class 'jax.numpy.int64'> requested in array is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return jnp.array(cars, dtype=jnp.int_)
# Failed to load: Breakout-MinAtar UNKNOWN: Failed to determine best cudnn convolution algorithm for:
# %cudnn-conv.1 = (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,4,10,10]{3,2,1,0} %bitcast.39, f32[16,4,5,5]{3,2,1,0} %bitcast.46), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(conv_general_dilated)/jit(main)/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
#
# Original error: INTERNAL: All algorithms tried for (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,4,10,10]{3,2,1,0}, f32[16,4,5,5]{3,2,1,0}), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} failed. Falling back to default algorithm.  Per-algorithm errors:
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=3,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng3{k11=2}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng4{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#
# To ignore this failure and try to use a fallback algorithm (which may have suboptimal performance), use XLA_FLAGS=--xla_gpu_strict_conv_algorithm_picker=false.  Please also file a bug for the root cause of failing autotuning.
# 2025-10-13 13:00:11.041397: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:864] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.
# 2025-10-13 13:00:11.041416: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:867] Conv: %cudnn-conv.1 = (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,7,10,10]{3,2,1,0} %bitcast.39, f32[16,7,5,5]{3,2,1,0} %bitcast.46), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(conv_general_dilated)/jit(main)/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# Loading Problems ..:  75%|███████▌  | 3/4 [00:05<00:01,  1.96s/it]
# Failed to load: Freeway-MinAtar UNKNOWN: Failed to determine best cudnn convolution algorithm for:
# %cudnn-conv.1 = (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,7,10,10]{3,2,1,0} %bitcast.39, f32[16,7,5,5]{3,2,1,0} %bitcast.46), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(conv_general_dilated)/jit(main)/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
#
# Original error: INTERNAL: All algorithms tried for (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,7,10,10]{3,2,1,0}, f32[16,7,5,5]{3,2,1,0}), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} failed. Falling back to default algorithm.  Per-algorithm errors:
#   Profiling failure on cuDNN engine eng28{k2=3,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng3{k11=2}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng4{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#
# To ignore this failure and try to use a fallback algorithm (which may have suboptimal performance), use XLA_FLAGS=--xla_gpu_strict_conv_algorithm_picker=false.  Please also file a bug for the root cause of failing autotuning.
# 2025-10-13 13:00:11.375458: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:864] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.
# 2025-10-13 13:00:11.375479: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:867] Conv: %cudnn-conv.1 = (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,6,10,10]{3,2,1,0} %bitcast.39, f32[16,6,5,5]{3,2,1,0} %bitcast.46), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(conv_general_dilated)/jit(main)/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# Loading Problems ..: 100%|██████████| 4/4 [00:05<00:00,  1.36s/it]
# Failed to load: SpaceInvaders-MinAtar UNKNOWN: Failed to determine best cudnn convolution algorithm for:
# %cudnn-conv.1 = (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,6,10,10]{3,2,1,0} %bitcast.39, f32[16,6,5,5]{3,2,1,0} %bitcast.46), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(conv_general_dilated)/jit(main)/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
#
# Original error: INTERNAL: All algorithms tried for (f32[1,16,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,6,10,10]{3,2,1,0}, f32[16,6,5,5]{3,2,1,0}), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} failed. Falling back to default algorithm.  Per-algorithm errors:
#   Profiling failure on cuDNN engine eng28{k2=3,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng3{k11=2}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng4{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#
# To ignore this failure and try to use a fallback algorithm (which may have suboptimal performance), use XLA_FLAGS=--xla_gpu_strict_conv_algorithm_picker=false.  Please also file a bug for the root cause of failing autotuning.
