# %%
import sys
sys.path.append('/home/ronedr/evolution-strategy-baselines-comparison')

# %%
import jax
import optax
from evosax.problems import CNN, TorchVisionProblem as Problem, identity_output_fn
from tqdm import tqdm
from experiment.run_experiments import run_experiment_permutations
from evosax.core.fitness_shaping import standardize_fitness_shaping_fn

# %%
num_generations = 1000
population_size = 256
eval_batch_size = 32
log_period = 1
seeds = list(range(0, 5))
result_dir = "../../results"
problems_torch_vision = ["MNIST", "FashionMNIST", "CIFAR10", "SVHN"]

# %%
from evosax.core.fitness_shaping import centered_rank_fitness_shaping_fn

lr_schedule = optax.exponential_decay(
    init_value=0.01,
    transition_steps=num_generations,
    decay_rate=0.1,
)
std_schedule = optax.exponential_decay(
    init_value=0.05,
    transition_steps=num_generations,
    decay_rate=0.2,
)

es_dict = {
    # "Sep_CMA_ES": {},
    "Open_ES": {    
        "optimizer":optax.adam(learning_rate=lr_schedule),
        "std_schedule": std_schedule,
    },
    # "SNES": {},
    # "PGPE": {
    #     "optimizer": optax.adam(learning_rate=0.02)
    # },
    # "LES": {},
    # "ASEBO": {
    #     "optimizer": optax.adam(learning_rate=0.01),
    #     "fitness_shaping_fn": standardize_fitness_shaping_fn
    # },
    # ,
    # "DES": {},
    # "EvoTF_ES": {},
}

# take only the es_algorithms we insert as arg.
running_es = es_dict

# %%
for task_name in tqdm(problems_torch_vision, desc="Loading Problems .."):
    try:
        problem = Problem(task_name=task_name,
                          network=CNN(
                              num_filters=[8, 16],
                              kernel_sizes=[(5, 5), (5, 5)],
                              strides=[(1, 1), (1, 1)],
                              mlp_layer_sizes=[10],
                              output_fn=identity_output_fn
                          ),
                          batch_size=256)
        print("Successfully loaded:", task_name)
        run_experiment_permutations(problems=[problem],
                                    es_dict=running_es,
                                    num_generations=num_generations,
                                    population_size=population_size,
                                    result_dir=result_dir,
                                    run_again_if_exist=True,
                                    log_period=log_period,
                                    eval_batch_size=None,
                                    seeds=list(range(0, 5)))
    except Exception as e:
        print("Failed to load:", task_name, e)
        continue
# Out:
# Loading Problems ..:   0%|          | 0/4 [00:00<?, ?it/s]
# Successfully loaded: MNIST
# Running ES algorithms:   0%|          | 0/1 [00:00<?, ?it/s]
# running the experiment ... [../../results/TorchVisionProblem/MNIST/Open_ES/0]
# 2025-11-11 11:14:18.978267: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:864] None of the algorithms provided by cuDNN heuristics worked; trying fallback algorithms.
# 2025-11-11 11:14:18.978297: W external/xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:867] Conv: %cudnn-conv.6 = (f32[256,2048,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1,28,28]{3,2,1,0} %bitcast.16865, f32[2048,1,5,5]{3,2,1,0} %bitcast.16869), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(scan_step)/jit(main)/while/body/jit(eval)/vmap(CNN)/Conv_0/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
#
# Running ES algorithms: 100%|██████████| 1/1 [00:06<00:00,  6.43s/it]
# Loading Problems ..:  25%|██▌       | 1/4 [00:26<01:18, 26.05s/it]
# UNKNOWN: Failed to determine best cudnn convolution algorithm for:
# %cudnn-conv.6 = (f32[256,2048,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1,28,28]{3,2,1,0} %bitcast.16865, f32[2048,1,5,5]{3,2,1,0} %bitcast.16869), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_name="jit(scan_step)/jit(main)/while/body/jit(eval)/vmap(CNN)/Conv_0/conv_general_dilated" source_file="/home/ronedr/.local/lib/python3.11/site-packages/flax/linen/linear.py" source_line=694}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
#
# Original error: INTERNAL: All algorithms tried for (f32[256,2048,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[256,1,28,28]{3,2,1,0}, f32[2048,1,5,5]{3,2,1,0}), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} failed. Falling back to default algorithm.  Per-algorithm errors:
#   Profiling failure on cuDNN engine eng6{k25=2}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng4{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=1,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=0,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{k2=3,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng2{k2=4,k3=0}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng1{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng28{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#   Profiling failure on cuDNN engine eng0{}: UNKNOWN: CUDNN_STATUS_EXECUTION_FAILED
# in external/xla/xla/stream_executor/cuda/cuda_dnn.cc(6493): 'status'
#
# To ignore this failure and try to use a fallback algorithm (which may have suboptimal performance), use XLA_FLAGS=--xla_gpu_strict_conv_algorithm_picker=false.  Please also file a bug for the root cause of failing autotuning. Open_ES TorchVisionProblem/MNIST
# Loading Problems ..:  25%|██▌       | 1/4 [00:37<01:52, 37.66s/it]
#
# KeyboardInterrupt
