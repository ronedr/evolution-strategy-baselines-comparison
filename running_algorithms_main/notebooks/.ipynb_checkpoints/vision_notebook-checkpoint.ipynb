# %%
import os
import sys
sys.path.append('../../')
import jax
import optax
from typing import List

from evosax.problems import CNN, TorchVisionProblem, identity_output_fn
from evosax.algorithms import algorithms
from evosax.core.fitness_shaping import standardize_fitness_shaping_fn

from tqdm import tqdm
from utils.problem_utils import get_problem_settings
from experiment.experiment import Experiment
from utils.problem_utils import get_problem_name

# from experiment.run_experiments import run_experiment_permutations

# jax.config.update('jax_default_matmul_precision', 'tensorfloat32')
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 0 = all logs, 1 = filter INFO, 2 = filter WARNING, 3 = filter ERROR
# os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
# os.environ['XLA_FLAGS'] = '--xla_gpu_strict_conv_algorithm_picker=false --xla_gpu_autotune_level=1'

# %%
# num_generations = 100
# population_size = 128
NUM_GENERATIONS = 16
POPULATION_SIZE = 5
SEEDS = [0]
RESULT_DIR = "../../results"
PROBLEMS_TORCH_VISION = ["MNIST", "FashionMNIST", "CIFAR10", "SVHN"][:1]

# %%
es_dict = {
#     "PGPE": {
#         "optimizer": optax.adam(learning_rate=0.02),
#     },
#     "ASEBO": {
#         "optimizer": optax.adam(learning_rate=0.01),
#         "fitness_shaping_fn": standardize_fitness_shaping_fn
#     },
#     "LES": {
#         "optimizer": optax.adam(learning_rate=0.01)
#     },
#     "Open_ES": {    
#         "optimizer": optax.adam(learning_rate=0.05)
#     },
    
    # "SNES": {},
    # "Sep_CMA_ES": {},
    "CMA_ES": {},
    # "LES": {},
    # "DES": {},
    # "EvoTF_ES": {},
}

# take only the es_algorithms we insert as arg.
running_es = es_dict

# %%
from evosax.problems import Problem

def run_experiment_permutations(problems: List[Problem], es_dict: dict, num_generations: int, population_size: int,
                                result_dir: str, run_again_if_exist: bool = False,
                                seeds: list[int] = list(range(0, 5))):
    for problem in problems:
        for es_name in tqdm(es_dict, desc="Running ES algorithms"):
            try:
                for seed in seeds:
                    key = jax.random.key(seed)
                    key, subkey = jax.random.split(key)
                    solution = problem.sample(subkey)
                    es_algorithm = algorithms[es_name](population_size=population_size,
                                                       solution=solution,
                                                       **es_dict[es_name])
                    experiment = Experiment(problem=problem,
                                            algorithm=es_algorithm,
                                            results_dir_path=result_dir,
                                            seed=seed)

                    if not experiment.has_run() or run_again_if_exist:
                        print(f"running the experiment ... [{experiment.get_experiment_path_file()}]")
                        experiment.run(num_generations=num_generations)
                    else:
                        print(f"there is experiment results. [{experiment.get_experiment_path_file()}]")
            except Exception as e:
                print(e, es_name, get_problem_name(problem))
                raise e

# %%
for task_name in tqdm(PROBLEMS_TORCH_VISION, desc="Loading Problems .."):
    try:
        problem = TorchVisionProblem(task_name=task_name,
                          network=CNN(
                              num_filters=[4],
                              kernel_sizes=[(5, 5)],
                              strides=[(1, 1)],
                              mlp_layer_sizes=[10],
                              output_fn=identity_output_fn
                          ),
                          batch_size=2)
        print("Successfully loaded:", task_name)
        run_experiment_permutations(problems=[problem],
                                    es_dict=running_es,
                                    num_generations=NUM_GENERATIONS,
                                    population_size=POPULATION_SIZE,
                                    result_dir=RESULT_DIR, 
                                    run_again_if_exist=False,
                                    seeds=SEEDS)
    except Exception as e:
        print("Failed to load: " + task_name,'\nREASON:', e)
        raise e
# Out:
# Loading Problems ..:   0%|          | 0/1 [00:00<?, ?it/s]
# Successfully loaded: MNIST
# Running ES algorithms:   0%|          | 0/1 [00:00<?, ?it/s]
# running the experiment ... [../../results/TorchVisionProblem/MNIST/CMA_ES/0]
# 2025-10-23 14:34:59.402281: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3021] Can't reduce memory use below 2.75GiB (2952127356 bytes) by rematerialization; only reduced to 22.35GiB (23995460808 bytes), down from 22.35GiB (23996170348 bytes) originally
# 2025-10-23 14:35:14.440455: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.69GiB (rounded to 3964345856)requested by op
# 2025-10-23 14:35:14.440834: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] **************************************************************************************______________
# E1023 14:35:14.440886 3962181 pjrt_stream_executor_client.cc:3026] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3964345728 bytes. [tf-allocator-allocation-error='']
# Running ES algorithms:   0%|          | 0/1 [00:30<?, ?it/s]
# Loading Problems ..:   0%|          | 0/1 [00:44<?, ?it/s]
# RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3964345728 bytes. CMA_ES TorchVisionProblem/MNIST
# Failed to load: MNIST
# REASON: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3964345728 bytes.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[6], line 22
#      20 except Exception as e:
#      21     print("Failed to load: " + task_name,'\nREASON:', e)
# ---> 22     raise e
#
# Cell In[6], line 13
#       3     problem = TorchVisionProblem(task_name=task_name,
#       4                       network=CNN(
#       5                           num_filters=[4],
#    (...)
#      10                       ),
#      11                       batch_size=2)
#      12     print("Successfully loaded:", task_name)
# ---> 13     run_experiment_permutations(problems=[problem],
#      14                                 es_dict=running_es,
#      15                                 num_generations=NUM_GENERATIONS,
#      16                                 population_size=POPULATION_SIZE,
#      17                                 result_dir=RESULT_DIR,
#      18                                 run_again_if_exist=False,
#      19                                 seeds=SEEDS)
#      20 except Exception as e:
#      21     print("Failed to load: " + task_name,'\nREASON:', e)
#
# Cell In[5], line 28, in run_experiment_permutations(problems, es_dict, num_generations, population_size, result_dir, run_again_if_exist, seeds)
#      26 except Exception as e:
#      27     print(e, es_name, get_problem_name(problem))
# ---> 28     raise e
#
# Cell In[5], line 23, in run_experiment_permutations(problems, es_dict, num_generations, population_size, result_dir, run_again_if_exist, seeds)
#      21 if not experiment.has_run() or run_again_if_exist:
#      22     print(f"running the experiment ... [{experiment.get_experiment_path_file()}]")
# ---> 23     experiment.run(num_generations=num_generations)
#      24 else:
#      25     print(f"there is experiment results. [{experiment.get_experiment_path_file()}]")
#
# File ~/PHD/git_repo_fixed/evolution-strategy-baselines-comparison/running_algorithms_main/notebooks/../../experiment/experiment.py:48, in Experiment.run(self, num_generations)
#      46 key, subkey = jax.random.split(key)
#      47 keys = jax.random.split(subkey, self.LOG_PARIOD)
# ---> 48 (state, params, problem_state), metrics = jax.lax.scan(
#      49     self._step,
#      50     (state, params, problem_state),
#      51     keys,
#      52 )
#      53 collected_metrics.append(metrics)
#      54 if isinstance(self._problem, TorchVisionProblem):
#
#     [... skipping hidden 12 frame]
#
# File ~/.conda/envs/phdEnv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1296, in ExecuteReplicated.__call__(self, *args)
#    1294   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1295 else:
# -> 1296   results = self.xla_executable.execute_sharded(input_bufs)
#    1298 if dispatch.needs_check_special():
#    1299   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3964345728 bytes.
