# %%
import sys
sys.path.append('/home/ronedr/evolution-strategy-baselines-comparison')
sys.path.append('../../')

# %%
from tqdm import tqdm
import optax
from evosax.problems import BBOBProblem as Problem, bbob_fns
from experiment.utils.problem_utils import get_problem_settings
from experiment.run_experiments import run_experiment_permutations
from evosax.core.fitness_shaping import standardize_fitness_shaping_fn
# Out:
# Failed to import warp: No module named 'warp'
# Failed to import mujoco_warp: No module named 'warp'

# %%
num_generations = 1024
population_size = 10
eval_batch_size = 128
log_period = 1
num_dims = 10
seeds = list(range(0, 5))
result_dir = "../../results"
problems_bbob_fns = list(bbob_fns.keys())

# %%
lr_schedule = optax.exponential_decay(
    init_value=0.01,
    transition_steps=num_generations,
    decay_rate=0.1,
)
std_schedule = optax.exponential_decay(
    init_value=0.05,
    transition_steps=num_generations,
    decay_rate=0.2,
)

es_dict = {
    "Open_ES": {    
        "optimizer": optax.adam(learning_rate=lr_schedule), 
        "std_schedule": std_schedule
    },
    "PGPE": {
        "optimizer": optax.adam(learning_rate=0.02),
    },
    "ASEBO": {
        "optimizer": optax.adam(learning_rate=0.01),
        "fitness_shaping_fn": standardize_fitness_shaping_fn
    },
    "LES": {},
    "SNES": {},
    "Sep_CMA_ES": {},
    "CMA_ES": {},
    "DES": {},
    # "EvoTF_ES": {},
}

running_es = es_dict

# %%
for bbob_fn in tqdm(problems_bbob_fns, desc="Loading Problems .."):
    try:
        problem = Problem(fn_name=bbob_fn, num_dims=num_dims)
        print("Successfully loaded:", bbob_fn)
        run_experiment_permutations(problems=[problem],
                                    es_dict=running_es,
                                    num_generations=num_generations,
                                    population_size=population_size,
                                    result_dir=result_dir, 
                                    run_again_if_exist=True,
                                    log_period=log_period,
                                    eval_batch_size=eval_batch_size,
                                    suffix_experiment_name=f"{population_size}_{num_dims}",
                                    seeds=list(range(0, 5)))
    except Exception as e:
        print("Failed to load:", bbob_fn, e)
        continue
# Out:
# Loading Problems ..:   0%|          | 0/24 [00:00<?, ?it/s]2025-11-09 00:07:29.734480: W external/xla/xla/service/platform_util.cc:211] unable to create StreamExecutor for CUDA:0: : CUDA_ERROR_OUT_OF_MEMORY: out of memory
# Loading Problems ..:   4%|▍         | 1/24 [00:00<00:14,  1.60it/s]
# Failed to load: sphere Unable to initialize backend 'cuda': INTERNAL: no supported devices found for platform CUDA (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)
# Loading Problems ..:   8%|▊         | 2/24 [00:01<00:21,  1.03it/s]
# Successfully loaded: ellipsoidal
# Failed to load: ellipsoidal name 'running_es' is not defined
# Loading Problems ..:  12%|█▎        | 3/24 [00:02<00:19,  1.08it/s]
# Successfully loaded: rastrigin
# Failed to load: rastrigin name 'running_es' is not defined
# Loading Problems ..:  17%|█▋        | 4/24 [00:03<00:18,  1.09it/s]
# Successfully loaded: bueche_rastrigin
# Failed to load: bueche_rastrigin name 'running_es' is not defined
# Loading Problems ..:  21%|██        | 5/24 [00:04<00:17,  1.11it/s]
# Successfully loaded: linear_slope
# Failed to load: linear_slope name 'running_es' is not defined
# Loading Problems ..:  25%|██▌       | 6/24 [00:05<00:16,  1.11it/s]
# Successfully loaded: attractive_sector
# Failed to load: attractive_sector name 'running_es' is not defined
# Loading Problems ..:  29%|██▉       | 7/24 [00:06<00:14,  1.14it/s]
# Successfully loaded: step_ellipsoidal
# Failed to load: step_ellipsoidal name 'running_es' is not defined
# Loading Problems ..:  33%|███▎      | 8/24 [00:07<00:13,  1.15it/s]
# Successfully loaded: rosenbrock
# Failed to load: rosenbrock name 'running_es' is not defined
# Loading Problems ..:  38%|███▊      | 9/24 [00:07<00:12,  1.16it/s]
# Successfully loaded: rosenbrock_rotated
# Failed to load: rosenbrock_rotated name 'running_es' is not defined
# Loading Problems ..:  42%|████▏     | 10/24 [00:08<00:12,  1.09it/s]
# Successfully loaded: ellipsoidal_rotated
# Failed to load: ellipsoidal_rotated name 'running_es' is not defined
# Loading Problems ..:  46%|████▌     | 11/24 [00:09<00:11,  1.11it/s]
# Successfully loaded: discus
# Failed to load: discus name 'running_es' is not defined
# Loading Problems ..:  50%|█████     | 12/24 [00:10<00:10,  1.13it/s]
# Successfully loaded: bent_cigar
# Failed to load: bent_cigar name 'running_es' is not defined
# Loading Problems ..:  54%|█████▍    | 13/24 [00:11<00:09,  1.12it/s]
# Successfully loaded: sharp_ridge
# Failed to load: sharp_ridge name 'running_es' is not defined
# Loading Problems ..:  58%|█████▊    | 14/24 [00:12<00:08,  1.13it/s]
# Successfully loaded: different_powers
# Failed to load: different_powers name 'running_es' is not defined
# Loading Problems ..:  62%|██████▎   | 15/24 [00:13<00:07,  1.13it/s]
# Successfully loaded: rastrigin_rotated
# Failed to load: rastrigin_rotated name 'running_es' is not defined
# Loading Problems ..:  67%|██████▋   | 16/24 [00:14<00:07,  1.12it/s]
# Successfully loaded: weierstrass
# Failed to load: weierstrass name 'running_es' is not defined
# Loading Problems ..:  71%|███████   | 17/24 [00:15<00:06,  1.11it/s]
# Successfully loaded: schaffers_f7
# Failed to load: schaffers_f7 name 'running_es' is not defined
# Loading Problems ..:  75%|███████▌  | 18/24 [00:16<00:05,  1.12it/s]
# Successfully loaded: schaffers_f7_ill_cond
# Failed to load: schaffers_f7_ill_cond name 'running_es' is not defined
# Loading Problems ..:  79%|███████▉  | 19/24 [00:16<00:04,  1.11it/s]
# Successfully loaded: griewank_rosenbrock
# Failed to load: griewank_rosenbrock name 'running_es' is not defined
# Loading Problems ..:  83%|████████▎ | 20/24 [00:17<00:03,  1.12it/s]
# Successfully loaded: schwefel
# Failed to load: schwefel name 'running_es' is not defined
# Loading Problems ..:  88%|████████▊ | 21/24 [00:18<00:02,  1.14it/s]
# Successfully loaded: gallagher_101_me
# Failed to load: gallagher_101_me name 'running_es' is not defined
# Loading Problems ..:  92%|█████████▏| 22/24 [00:19<00:01,  1.13it/s]
# Successfully loaded: gallagher_21_hi
# Failed to load: gallagher_21_hi name 'running_es' is not defined
# Loading Problems ..:  96%|█████████▌| 23/24 [00:20<00:00,  1.14it/s]
# Successfully loaded: katsuura
# Failed to load: katsuura name 'running_es' is not defined
# Loading Problems ..: 100%|██████████| 24/24 [00:21<00:00,  1.13it/s]
# Successfully loaded: lunacek
# Failed to load: lunacek name 'running_es' is not defined
